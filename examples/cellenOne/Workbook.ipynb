# %%
import proteolyzer as pz
mapper = pz.cellenone.CoordinatesMapping(root_dir = 'cellenone_files', label_type = 'mTRAQ', plex = 2)
mapper.map_data()
# Out:
# Found 4 Geoprops files.
# Found 4 Dispense files.
# Found 1 Label files.
# Found 1 Pickup files.
#      DropNo.Geoprops  X.Geoprops  Y.Geoprops  Diameter.Geoprops  \
# 0              260.0      205.19      164.13              18.13
# 1              293.0      112.77      142.98              28.91
# 2              308.0        7.60      113.43              20.41
# 3              323.0      131.89      197.00              18.64
# 4              402.0      178.19      196.77              17.96
# ..               ...         ...         ...                ...
# 139           4532.0      155.86      192.56              18.29
# 140           5006.0      148.27      159.40              19.48
# 141           5093.0      213.53      210.69              22.51
# 142           5124.0      163.97      206.81              19.18
# 143           5518.0      230.95      193.16              23.55
#
#      Elongation.Geoprops  Circularity.Geoprops  Intensity.Geoprops  \
# ...

# %%
# If you use the wrong configuration, such as not specifying the correct label type or plex number, it will warn the user about well clashes. 
# This is to indicate that cells should only be picked up and placed into the same well on the same plate only if they are labelled differently.
mapper = pz.cellenone.CoordinatesMapping(root_dir = 'cellenone_files')
mapper.map_data()
# Out:
# Found 4 Geoprops files.
# Found 4 Dispense files.
# Found 1 Label files.
# Found 1 Pickup files.
# WARNING - 2025-12-24 15:03:50 - _metadata_validate - CoordinatesMapping - Well clashes detected! Check Well.Clash column to view clashes.
#      DropNo.Geoprops  X.Geoprops  Y.Geoprops  Diameter.Geoprops  \
# 0              260.0      205.19      164.13              18.13
# 1              293.0      112.77      142.98              28.91
# 2              308.0        7.60      113.43              20.41
# 3              323.0      131.89      197.00              18.64
# 4              402.0      178.19      196.77              17.96
# ..               ...         ...         ...                ...
# 139           4532.0      155.86      192.56              18.29
# 140           5006.0      148.27      159.40              19.48
# 141           5093.0      213.53      210.69              22.51
# 142           5124.0      163.97      206.81              19.18
# ...
